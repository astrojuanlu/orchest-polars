# %% [markdown]
# ## First steps with Polars

# %%
import polars as pl

# %%
# !du -sh /data/stacksample/*
# Out:
# 1.8G	/data/stacksample/Questions.csv
# 63M	/data/stacksample/Tags.csv

# %%
df = pl.read_csv("/data/stacksample/Questions.csv", encoding="utf8-lossy")
df.head()
# Out:
# shape: (5, 7)
# ┌─────┬─────────────┬─────────────────┬─────────────────┬───────┬─────────────────┬────────────────┐
# │ Id  ┆ OwnerUserId ┆ CreationDate    ┆ ClosedDate      ┆ Score ┆ Title           ┆ Body           │
# │ --- ┆ ---         ┆ ---             ┆ ---             ┆ ---   ┆ ---             ┆ ---            │
# │ i64 ┆ str         ┆ str             ┆ str             ┆ i64   ┆ str             ┆ str            │
# ╞═════╪═════════════╪═════════════════╪═════════════════╪═══════╪═════════════════╪════════════════╡
# │ 80  ┆ 26          ┆ 2008-08-01T13:5 ┆ NA              ┆ 26    ┆ SQLStatement.ex ┆ <p>I've        │
# │     ┆             ┆ 7:07Z           ┆                 ┆       ┆ ecute() -       ┆ written a      │
# │     ┆             ┆                 ┆                 ┆       ┆ multipl...      ┆ database       │
# │     ┆             ┆                 ┆                 ┆       ┆                 ┆ gener...       │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 90  ┆ 58          ┆ 2008-08-01T14:4 ┆ 2012-12-26T03:4 ┆ 144   ┆ Good branching  ┆ <p>Are there   │
# │     ┆             ┆ 1:24Z           ┆ 5:49Z           ┆       ┆ and merging     ┆ any really     │
# │     ┆             ┆                 ┆                 ┆       ┆ tutor...        ┆ good tut...    │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 120 ┆ 83          ┆ 2008-08-01T15:5 ┆ NA              ┆ 21    ┆ ASP.NET Site    ┆ <p>Has anyone  │
# │     ┆             ┆ 0:08Z           ┆                 ┆       ┆ Maps            ┆ got experience │
# │     ┆             ┆                 ┆                 ┆       ┆                 ┆ cre...         │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 180 ┆ 2089740     ┆ 2008-08-01T18:4 ┆ NA              ┆ 53    ┆ Function for    ┆ <p>This is     │
# │     ┆             ┆ 2:19Z           ┆                 ┆       ┆ creating color  ┆ something I've │
# │     ┆             ┆                 ┆                 ┆       ┆ whee...         ┆ pseudo...      │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 260 ┆ 91          ┆ 2008-08-01T23:2 ┆ NA              ┆ 49    ┆ Adding          ┆ <p>I have a    │
# │     ┆             ┆ 2:08Z           ┆                 ┆       ┆ scripting       ┆ little game    │
# │     ┆             ┆                 ┆                 ┆       ┆ functionality   ┆ written ...    │
# │     ┆             ┆                 ┆                 ┆       ┆ t...            ┆                │
# └─────┴─────────────┴─────────────────┴─────────────────┴───────┴─────────────────┴────────────────┘

# %%
tags = pl.read_csv("/data/stacksample/Tags.csv")
tags.head()
# Out:
# shape: (5, 2)
# ┌─────┬────────────────┐
# │ Id  ┆ Tag            │
# │ --- ┆ ---            │
# │ i64 ┆ str            │
# ╞═════╪════════════════╡
# │ 80  ┆ flex           │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 80  ┆ actionscript-3 │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 80  ┆ air            │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 90  ┆ svn            │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 90  ┆ tortoisesvn    │
# └─────┴────────────────┘

# %%
type(df)
# Out:
# polars.internals.frame.DataFrame

# %%
len(df), len(tags)
# Out:
# (1264216, 3750994)

# %%
df.dtypes
# Out:
# [polars.datatypes.Int64,
#  polars.datatypes.Utf8,
#  polars.datatypes.Utf8,
#  polars.datatypes.Utf8,
#  polars.datatypes.Int64,
#  polars.datatypes.Utf8,
#  polars.datatypes.Utf8]

# %%
print(f"Estimated size: {df.estimated_size() >> 20} MiB")
# Out:
# Estimated size: 1865 MiB

# %%
print(df.head(3))
# Out:
# shape: (3, 7)
# ┌─────┬─────────────┬─────────────────┬─────────────────┬───────┬─────────────────┬────────────────┐
# │ Id  ┆ OwnerUserId ┆ CreationDate    ┆ ClosedDate      ┆ Score ┆ Title           ┆ Body           │
# │ --- ┆ ---         ┆ ---             ┆ ---             ┆ ---   ┆ ---             ┆ ---            │
# │ i64 ┆ str         ┆ str             ┆ str             ┆ i64   ┆ str             ┆ str            │
# ╞═════╪═════════════╪═════════════════╪═════════════════╪═══════╪═════════════════╪════════════════╡
# │ 80  ┆ 26          ┆ 2008-08-01T13:5 ┆ NA              ┆ 26    ┆ SQLStatement.ex ┆ <p>I've        │
# │     ┆             ┆ 7:07Z           ┆                 ┆       ┆ ecute() -       ┆ written a      │
# │     ┆             ┆                 ┆                 ┆       ┆ multipl...      ┆ database       │
# │     ┆             ┆                 ┆                 ┆       ┆                 ┆ gener...       │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 90  ┆ 58          ┆ 2008-08-01T14:4 ┆ 2012-12-26T03:4 ┆ 144   ┆ Good branching  ┆ <p>Are there   │
# │     ┆             ┆ 1:24Z           ┆ 5:49Z           ┆       ┆ and merging     ┆ any really     │
# │     ┆             ┆                 ┆                 ┆       ┆ tutor...        ┆ good tut...    │
# ├╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 120 ┆ 83          ┆ 2008-08-01T15:5 ┆ NA              ┆ 21    ┆ ASP.NET Site    ┆ <p>Has anyone  │
# │     ┆             ┆ 0:08Z           ┆                 ┆       ┆ Maps            ┆ got experience │
# │     ┆             ┆                 ┆                 ┆       ┆                 ┆ cre...         │
# └─────┴─────────────┴─────────────────┴─────────────────┴───────┴─────────────────┴────────────────┘

# %%
df.describe()
# Out:
# shape: (5, 8)
# ┌──────────┬─────────────┬─────────────┬──────────────┬────────────┬───────────┬───────┬──────┐
# │ describe ┆ Id          ┆ OwnerUserId ┆ CreationDate ┆ ClosedDate ┆ Score     ┆ Title ┆ Body │
# │ ---      ┆ ---         ┆ ---         ┆ ---          ┆ ---        ┆ ---       ┆ ---   ┆ ---  │
# │ str      ┆ f64         ┆ str         ┆ str          ┆ str        ┆ f64       ┆ str   ┆ str  │
# ╞══════════╪═════════════╪═════════════╪══════════════╪════════════╪═══════════╪═══════╪══════╡
# │ mean     ┆ 2.1327e7    ┆ null        ┆ null         ┆ null       ┆ 1.781537  ┆ null  ┆ null │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ std      ┆ 1.1514e7    ┆ null        ┆ null         ┆ null       ┆ 13.663886 ┆ null  ┆ null │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ min      ┆ 80.0        ┆ null        ┆ null         ┆ null       ┆ -73.0     ┆ null  ┆ null │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ max      ┆ 4.014338e7  ┆ null        ┆ null         ┆ null       ┆ 5190.0    ┆ null  ┆ null │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌┤
# │ median   ┆ 2.1725415e7 ┆ null        ┆ null         ┆ null       ┆ 0.0       ┆ null  ┆ null │
# └──────────┴─────────────┴─────────────┴──────────────┴────────────┴───────────┴───────┴──────┘

# %%
tags["Tag"].value_counts().head()
# Out:
# shape: (5, 2)
# ┌────────────┬────────┐
# │ Tag        ┆ counts │
# │ ---        ┆ ---    │
# │ str        ┆ u32    │
# ╞════════════╪════════╡
# │ javascript ┆ 124155 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ java       ┆ 115212 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ c#         ┆ 101186 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ php        ┆ 98808  │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┤
# │ android    ┆ 90659  │
# └────────────┴────────┘

# %%
df.dtypes
# Out:
# [polars.datatypes.Int64,
#  polars.datatypes.Utf8,
#  polars.datatypes.Utf8,
#  polars.datatypes.Utf8,
#  polars.datatypes.Int64,
#  polars.datatypes.Utf8,
#  polars.datatypes.Utf8]

# %% [markdown]
# ## Expressions as chained operations on columns

# %%
(
    pl.col("Score")
    .median()
)
# Out:
# col("Score").median()

# %%
print(df.select(pl.col("Score").mean()))
# Out:
# shape: (1, 1)
# ┌──────────┐
# │ Score    │
# │ ---      │
# │ f64      │
# ╞══════════╡
# │ 1.781537 │
# └──────────┘

# %%
print(df.select([
    pl.col("Id").n_unique().alias("num_unique_users"),
    pl.col("Score").mean().alias("mean_score"),
    pl.col("Title").str.lengths().max().alias("max_title_length"),
    # pl.col(pl.Utf8).str.lengths().max().suffix("_max_length"),
]))
# Out:
# shape: (1, 3)
# ┌──────────────────┬────────────┬──────────────────┐
# │ num_unique_users ┆ mean_score ┆ max_title_length │
# │ ---              ┆ ---        ┆ ---              │
# │ u32              ┆ f64        ┆ u32              │
# ╞══════════════════╪════════════╪══════════════════╡
# │ 1264216          ┆ 1.781537   ┆ 204              │
# └──────────────────┴────────────┴──────────────────┘

# %%
pl.col("Tag").arr.lengths()
# Out:
# col("Tag").arr.len()

# %% [markdown]
# ### The power of laziness

# %%
# Don't try this at home unless you have enough RAM!
# (
#     df
#     .join(tags, on="Id")
#     .filter(pl.col("Tag").str.to_lowercase().str.contains("python"))
#     .sort("Id")
# )

# %%
q_python = (
    df.lazy()  # Notice the .lazy() call
    # The input of a lazy join needs to be lazy
    # We use a 'semi' join, like 'inner' but discarding extra columns
    .join(tags.lazy(), on="Id", how="semi")
    .filter(pl.col("Tag").str.to_lowercase().str.contains("python"))
    .sort("Id")
).collect()  # Call .collect() at the end
print(q_python.head(3))
# Out:
# shape: (3, 7)
# ┌───────┬─────────────┬──────────────────┬────────────┬───────┬──────────────────┬─────────────────┐
# │ Id    ┆ OwnerUserId ┆ CreationDate     ┆ ClosedDate ┆ Score ┆ Title            ┆ Body            │
# │ ---   ┆ ---         ┆ ---              ┆ ---        ┆ ---   ┆ ---              ┆ ---             │
# │ i64   ┆ str         ┆ str              ┆ str        ┆ i64   ┆ str              ┆ str             │
# ╞═══════╪═════════════╪══════════════════╪════════════╪═══════╪══════════════════╪═════════════════╡
# │ 11060 ┆ 912         ┆ 2008-08-14T13:59 ┆ NA         ┆ 18    ┆ How should I     ┆ <p>This is a    │
# │       ┆             ┆ :21Z             ┆            ┆       ┆ unit test a      ┆ difficult and   │
# │       ┆             ┆                  ┆            ┆       ┆ code-ge...       ┆ open-...        │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 17250 ┆ 394         ┆ 2008-08-20T00:16 ┆ NA         ┆ 24    ┆ Create an        ┆ <p>I'm creating │
# │       ┆             ┆ :40Z             ┆            ┆       ┆ encrypted ZIP    ┆ an ZIP file     │
# │       ┆             ┆                  ┆            ┆       ┆ file in ...      ┆ with...         │
# ├╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 19030 ┆ 745         ┆ 2008-08-20T22:50 ┆ NA         ┆ 2     ┆ How to check set ┆ <p>I have a     │
# │       ┆             ┆ :55Z             ┆            ┆       ┆ of files         ┆ bunch of files  │
# │       ┆             ┆                  ┆            ┆       ┆ confor...        ┆ (TV e...        │
# └───────┴─────────────┴──────────────────┴────────────┴───────┴──────────────────┴─────────────────┘

# %%
plan = (
    # scan_csv returns a lazy dataframe already
    pl.scan_csv("/data/stacksample/Questions.csv", encoding="utf8-lossy")
    .join(tags.lazy(), on="Id", how="semi")
    .filter(pl.col("Tag").str.to_lowercase().str.contains("python"))
    .sort("Score", reverse=True)
    .limit(1_000)
)
top_voted_python_qs = plan.collect()

# %%
plan.show_graph(optimized=False)

# %% [markdown]
# ### Working with columns of lists

# %%
tag_list_lazy = (
    tags.lazy()
    .groupby("Id").agg(
        pl.col("Tag")
        .list()
        .alias("TagList")
    )
)
print(tag_list_lazy.limit(5).collect())
# Out:
# shape: (5, 2)
# ┌──────────┬─────────────────────────────────────┐
# │ Id       ┆ TagList                             │
# │ ---      ┆ ---                                 │
# │ i64      ┆ list [str]                          │
# ╞══════════╪═════════════════════════════════════╡
# │ 17463680 ┆ ["java", "generics"]                │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 35111500 ┆ ["jquery", "html", ... "wordpres... │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 25270390 ┆ ["cuda", "opencl", ... "pci-e"]     │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 32172780 ┆ ["rust"]                            │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 10380640 ┆ ["eclipse", "scala"]                │
# └──────────┴─────────────────────────────────────┘

# %%
tag_list_extended_lazy = tag_list_lazy.with_column(
    pl.col("TagList")
    .arr.eval(
        pl.element()
        .str.to_lowercase()
        .str.contains("python")
        .any()
    ).flatten().alias("ContainsPython")
)
tag_list_extended_lazy.sort("Id", reverse=True).limit(10).collect()
# Out:
# shape: (10, 3)
# ┌──────────┬─────────────────────────────────────┬────────────────┐
# │ Id       ┆ TagList                             ┆ ContainsPython │
# │ ---      ┆ ---                                 ┆ ---            │
# │ i64      ┆ list [str]                          ┆ bool           │
# ╞══════════╪═════════════════════════════════════╪════════════════╡
# │ 40143380 ┆ ["npm", "mocha", "babel"]           ┆ false          │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 40143360 ┆ ["javascript", "vue.js"]            ┆ false          │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 40143340 ┆ ["android", "android-studio"]       ┆ false          │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 40143300 ┆ ["google-bigquery"]                 ┆ false          │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...      ┆ ...                                 ┆ ...            │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 40143170 ┆ ["laravel", "binding", ... "rout... ┆ false          │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 40143150 ┆ ["javascript", "youtube", "youtu... ┆ false          │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 40143140 ┆ ["spring-data-rest"]                ┆ false          │
# ├╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 40143110 ┆ ["android", "android-activity", ... ┆ false          │
# └──────────┴─────────────────────────────────────┴────────────────┘

# %%
top_python_questions = (
    pl.scan_csv("/data/stacksample/Questions.csv", encoding="utf8-lossy")
    .join(tag_list_extended_lazy, on="Id")
    .filter(pl.col("ContainsPython"))
    .sort("Score", reverse=True)
).limit(1_000).collect()

# %%
top_python_questions.select(pl.all().exclude("Body")).head()
# Out:
# shape: (5, 8)
# ┌─────────┬───────────┬────────────┬────┬───────┬─────────────────────┬───────────────┬────────────┐
# │ Id      ┆ OwnerUser ┆ CreationDa ┆ Cl ┆ Score ┆ Title               ┆ TagList       ┆ ContainsPy │
# │ ---     ┆ Id        ┆ te         ┆ os ┆ ---   ┆ ---                 ┆ ---           ┆ thon       │
# │ i64     ┆ ---       ┆ ---        ┆ ed ┆ i64   ┆ str                 ┆ list [str]    ┆ ---        │
# │         ┆ str       ┆ str        ┆ Da ┆       ┆                     ┆               ┆ bool       │
# │         ┆           ┆            ┆ te ┆       ┆                     ┆               ┆            │
# │         ┆           ┆            ┆ -- ┆       ┆                     ┆               ┆            │
# │         ┆           ┆            ┆ -  ┆       ┆                     ┆               ┆            │
# │         ┆           ┆            ┆ st ┆       ┆                     ┆               ┆            │
# │         ┆           ┆            ┆ r  ┆       ┆                     ┆               ┆            │
# ╞═════════╪═══════════╪════════════╪════╪═══════╪═════════════════════╪═══════════════╪════════════╡
# │ 306400  ┆ 4872      ┆ 2008-11-20 ┆ NA ┆ 824   ┆ How do I randomly   ┆ ["python",    ┆ true       │
# │         ┆           ┆ T18:42:21Z ┆    ┆       ┆ select an item...   ┆ "list",       ┆            │
# │         ┆           ┆            ┆    ┆       ┆                     ┆ "random"]     ┆            │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 2052390 ┆ 179736    ┆ 2010-01-12 ┆ NA ┆ 797   ┆ Manually raising    ┆ ["python",    ┆ true       │
# │         ┆           ┆ T21:07:40Z ┆    ┆       ┆ (throwing) an e...  ┆ "exception",  ┆            │
# │         ┆           ┆            ┆    ┆       ┆                     ┆ "excepti...   ┆            │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 541390  ┆ 85185     ┆ 2009-02-12 ┆ NA ┆ 599   ┆ Extracting          ┆ ["python",    ┆ true       │
# │         ┆           ┆ T14:11:50Z ┆    ┆       ┆ extension from      ┆ "filenames",  ┆            │
# │         ┆           ┆            ┆    ┆       ┆ filena...           ┆ "file-ex...   ┆            │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 152580  ┆ 14102     ┆ 2008-09-30 ┆ NA ┆ 588   ┆ What's the          ┆ ["python",    ┆ true       │
# │         ┆           ┆ T11:00:10Z ┆    ┆       ┆ canonical way to    ┆ "types"]      ┆            │
# │         ┆           ┆            ┆    ┆       ┆ chec...             ┆               ┆            │
# ├╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1534210 ┆ 51208     ┆ 2009-10-07 ┆ NA ┆ 501   ┆ Use different       ┆ ["python",    ┆ true       │
# │         ┆           ┆ T21:11:22Z ┆    ┆       ┆ Python version      ┆ "virtualenv", ┆            │
# │         ┆           ┆            ┆    ┆       ┆ wit...              ┆ "virtua...    ┆            │
# └─────────┴───────────┴────────────┴────┴───────┴─────────────────────┴───────────────┴────────────┘
